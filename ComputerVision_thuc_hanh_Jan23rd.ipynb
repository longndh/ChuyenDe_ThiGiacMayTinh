# %%
#Dùng OpenCV để nhận diện khuôn mặt người

import numpy as np
import cv2 as cv

face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')

img = cv.imread('aCouple.jpg')
gray = cv.cvtColor(img, cv.COLOR_RGB2GRAY)

faces = face_cascade.detectMultiScale(gray, 1.1, 5)
for (x,y,w,h) in faces:
    cv.rectangle(img, (x,y), (x+w,y+h), (255,0,0), 2)

# %%
#Hiển thị ảnh trên jupyter notebook
from matplotlib import pyplot as plt

#cv2 đọc ảnh theo bảng màu BGR, cần chuyển về RGB để hiển thị bằng pyplot
im = cv.cvtColor(img, cv.COLOR_BGR2RGB)

plt.rcParams["figure.figsize"] = (12, 12)
plt.imshow(im)
plt.show()

# %%
#Hiển thị ảnh trên một cửa sổ mới
cv.imshow('img',img)
cv.waitKey(0)
cv.destroyAllWindows()
